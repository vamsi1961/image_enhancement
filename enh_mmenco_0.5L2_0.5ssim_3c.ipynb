# %%
import tensorflow
import keras
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense ,Conv2D ,Conv2DTranspose ,Dropout ,BatchNormalization ,Input ,MaxPooling2D ,concatenate
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random
import os
from tensorflow.keras.optimizers import Adam
from google.colab.patches import cv2_imshow

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
train_input_dir = '/content/gdrive/My Drive/train_input_870'
train_output_dir = '/content/gdrive/My Drive/train_output_870'
test_input_dir = '/content/gdrive/My Drive/test_output_20'
test_output_dir = '/content/gdrive/My Drive/test_output_20'
print(os.listdir(test_input_dir))
# Out:
# ['15136.png', '15418.png', '15426.png', '15544.png', '15704.png']

# %%
def images(dir_train,dir_test):
  images = os.listdir(dir_train)
  images_ = os.listdir(dir_test)
  k = random.choice(images)
  file_train = dir_train + '/' + k
  file_test = dir_test + '/' + k
  print(len(images))
  print(len(images_))
  img = cv2.resize(cv2.imread(file_train),(256,256))
  img_ = cv2.resize(cv2.imread(file_test),(256,256))
  cv2_imshow(img)
  cv2_imshow(img_)

# %%
images(train_input_dir,train_output_dir)
# Out:
# 885
# 885
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F25197AD6A0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F25197AD748>

# %%
def conv_model(hidden_size):
    input_layer = Input((256,256,3))
    conv_1 = Conv2D(hidden_size * 1,(3,3),activation = "relu" ,padding = "same")(input_layer)
    conv_1 = Conv2D(hidden_size * 1,(3,3),activation = "relu" ,padding = "same")(conv_1)
    conv_1 = Conv2D(hidden_size * 1,(1,1),activation = "relu" ,strides=(2,2))(conv_1)


    conv_2 = Conv2D(hidden_size * 2,(3,3),activation = "relu" ,padding = "same")(conv_1)
    conv_2 = Conv2D(hidden_size * 2,(3,3),activation = "relu" ,padding = "same")(conv_2)
    conv_2 = Conv2D(hidden_size * 2,(1,1),activation = "relu" ,strides=(2,2))(conv_2)

    conv_3 = Conv2D(hidden_size * 4,(3,3),activation = "relu" ,padding = "same")(conv_2)
    conv_3 = Conv2D(hidden_size * 4,(3,3),activation = "relu" ,padding = "same")(conv_3)
    conv_3 = Conv2D(hidden_size * 4,(1,1),activation = "relu" ,strides=(2,2))(conv_3)

    conv_4 = Conv2D(hidden_size * 8,(3,3),activation = "relu" ,padding = "same")(conv_3)
    conv_4 = Conv2D(hidden_size * 8,(3,3),activation = "relu" ,padding = "same")(conv_4)
    conv_4 = Conv2D(hidden_size * 8,(1,1),activation = "relu" ,strides=(2,2))(conv_4)

    conv_5 = Conv2D(hidden_size * 16,(3,3),activation = "relu" ,padding = "same")(conv_4)
    conv_5 = Conv2D(hidden_size * 16,(3,3),activation = "relu" ,padding = "same")(conv_5)
    conv_5 = Conv2D(hidden_size * 16,(1,1),activation = "relu" ,strides=(2,2))(conv_5)   

    conv_m = Conv2D(hidden_size * 32,(3,3),activation = "relu" ,padding = "same")(conv_5)
    conv_m = Conv2D(hidden_size * 32,(3,3),activation = "relu" ,padding = "same")(conv_m)
    conv_m = Conv2D(hidden_size * 32,(1,1),activation = "relu" ,strides=(2,2))(conv_m)

    de_conv_5 = Conv2DTranspose(hidden_size * 16, (3, 3), strides=(2, 2), padding="same")(conv_m)
    de_conv_5 = concatenate([de_conv_5 , conv_5])
    de_conv_5 = Conv2D(hidden_size * 16, (3, 3), activation="relu", padding="same")(de_conv_5)
    de_conv_5 = Conv2D(hidden_size * 16, (3, 3), activation="relu", padding="same")(de_conv_5)


    de_conv_4 = Conv2DTranspose(hidden_size * 8, (3, 3), strides=(2, 2), padding="same")(de_conv_5)
    de_conv_4 = concatenate([de_conv_4 , conv_4])
    de_conv_4 = Conv2D(hidden_size * 8, (3, 3), activation="relu", padding="same")(de_conv_4)
    de_conv_4 = Conv2D(hidden_size * 8, (3, 3), activation="relu", padding="same")(de_conv_4)

    de_conv_3 = Conv2DTranspose(hidden_size * 4, (3, 3), strides=(2, 2), padding="same")(de_conv_4)
    de_conv_3 = concatenate([de_conv_3 , conv_3])
    de_conv_3 = Conv2D(hidden_size * 4, (3, 3), activation="relu", padding="same")(de_conv_3)
    de_conv_3 = Conv2D(hidden_size * 4 ,(3, 3), activation="relu", padding="same")(de_conv_3)

    de_conv_2 = Conv2DTranspose(hidden_size * 2, (3, 3), strides=(2, 2), padding="same")(de_conv_3)
    de_conv_2 = concatenate([de_conv_2 , conv_2])
    de_conv_2 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_2)
    de_conv_2 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_2)

    de_conv_1 = Conv2DTranspose(hidden_size * 2, (3, 3), strides=(2, 2), padding="same")(de_conv_2)
    #de_conv_1 = concatenate([de_conv_1 , conv_1])
    de_conv_1 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_1)
    de_conv_1 = Conv2D(hidden_size * 2 ,(3, 3), activation="relu", padding="same")(de_conv_1)

    output_layer = Conv2D(3, (1,1), padding="same", activation="sigmoid")(de_conv_1)

    model = Model(inputs = [input_layer] ,outputs = [output_layer])
    return model


model = conv_model(32)

# %%
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 32) 1056        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 64) 18496       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 128, 128, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 64)   4160        conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 64, 64, 128)  73856       conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 128)  147584      conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 32, 32, 128)  16512       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 256)  295168      conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 16, 16, 256)  65792       conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 16, 16, 512)  1180160     conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 8, 8, 512)    262656      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 8, 8, 1024)   4719616     conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 8, 8, 1024)   9438208     conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 4, 4, 1024)   1049600     conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 8, 8, 512)    4719104     conv2d_17[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 8, 8, 1024)   0           conv2d_transpose[0][0]
#                                                                  conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 8, 8, 512)    4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 16, 16, 256)  1179904     conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 16, 16, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 32, 32, 128)  295040      conv2d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_2[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 64, 64, 64)   73792       conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_3[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 128, 128, 64) 36928       conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 128, 128, 3)  195         conv2d_27[0][0]
# ==================================================================================================
# Total params: 36,050,883
# Trainable params: 36,050,883
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
def loss_fn(y_true,y_pred):
    mse = tf.keras.losses.MeanSquaredError(reduction=tf.keras.losses.Reduction.SUM)
    k = mse(y_true, y_pred)
    k = (k/(256*256))
    ssim = tf.image.ssim(y_true *255 , y_pred * 255, max_val = 255, filter_size=11, filter_sigma=1.5, k1=0.01, k2=0.03)
    m = (1-ssim)/2
    return ((0.4*k) + (0.6*m))
model.compile(optimizer = Adam(lr = 0.0001),loss = loss_fn ,metrics = [tf.keras.metrics.MeanSquaredError()])

# %%
def load_file(fname ,path_input,path_output):
  image  = path_input + '/' + fname
  image_ = path_output + '/' + fname
  img = cv2.imread(image)
  img_ = cv2.imread(image_)
  img = cv2.resize(img,(256,256))
  img_ = cv2.resize(img_,(128,128))
  return(img,img_)

# %%
def data_generator(path_train,path_test,batch_size_):

  fnames_train = os.listdir(path_train)
  fnames_test = os.listdir(path_test)

  random.shuffle(fnames_train)
  random.shuffle(fnames_test)

  print(len(fnames_train))
  print(len(fnames_test))

  no_of_batches = len(fnames_train)//batch_size_

  for i in range(no_of_batches+1):
    X_train = []
    Y_train = []
    print('training batch no {}'.format(i+1))
    try:
      present_train = fnames_train[i*batch_size_:(i+1)*batch_size_]
      present_test  = fnames_test[i*batch_size_:(i+1)*batch_size_]
    except:
      present_train = fnames_train[i*batch_size_:]
      present_test  = fnames_test[i*batch_size_:]
      
    for name_train in present_train: 
      tup_train = load_file(name_train,path_train,path_test)
      X_train.append(tup_train[0])
      Y_train.append(tup_train[1])

    X_train = (np.asarray(X_train)/255.0)
    Y_train = (np.asarray(Y_train)/255.0)

    history = model.fit(X_train,Y_train,batch_size = 16 ,epochs = 80 ,verbose = 1,shuffle = True)

  return history

# %%
history = data_generator(train_input_dir,train_output_dir ,batch_size_ = 300)
# Out:
# 885
# 885
# training batch no 1
# Epoch 1/80
#  2/19 [==>...........................] - ETA: 1s - loss: 0.3197 - mean_squared_error: 0.0699WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0736s vs `on_train_batch_end` time: 0.1421s). Check your callbacks.
# 19/19 [==============================] - 6s 326ms/step - loss: 0.3368 - mean_squared_error: 0.0664
# Epoch 2/80
# 19/19 [==============================] - 4s 209ms/step - loss: 0.3313 - mean_squared_error: 0.0648
# Epoch 3/80
# 19/19 [==============================] - 4s 211ms/step - loss: 0.3012 - mean_squared_error: 0.0575
# Epoch 4/80
# 19/19 [==============================] - 4s 211ms/step - loss: 0.2538 - mean_squared_error: 0.0472
# Epoch 5/80
# 19/19 [==============================] - 4s 212ms/step - loss: 0.2118 - mean_squared_error: 0.0371
# Epoch 6/80
# 19/19 [==============================] - 4s 213ms/step - loss: 0.1942 - mean_squared_error: 0.0335
# Epoch 7/80
# 19/19 [==============================] - 4s 215ms/step - loss: 0.1830 - mean_squared_error: 0.0312
# Epoch 8/80
# 19/19 [==============================] - 4s 215ms/step - loss: 0.1814 - mean_squared_error: 0.0324
# Epoch 9/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.1783 - mean_squared_error: 0.0323
# Epoch 10/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.1673 - mean_squared_error: 0.0286
# Epoch 11/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.1646 - mean_squared_error: 0.0286
# Epoch 12/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.1586 - mean_squared_error: 0.0269
# Epoch 13/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1543 - mean_squared_error: 0.0260
# Epoch 14/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1508 - mean_squared_error: 0.0249
# Epoch 15/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.1468 - mean_squared_error: 0.0239
# Epoch 16/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1415 - mean_squared_error: 0.0221
# Epoch 17/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1359 - mean_squared_error: 0.0204
# Epoch 18/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.1350 - mean_squared_error: 0.0205
# Epoch 19/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.1315 - mean_squared_error: 0.0195
# Epoch 20/80
# 19/19 [==============================] - 4s 225ms/step - loss: 0.1288 - mean_squared_error: 0.0189
# Epoch 21/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.1329 - mean_squared_error: 0.0208
# Epoch 22/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1302 - mean_squared_error: 0.0201
# Epoch 23/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1273 - mean_squared_error: 0.0191
# Epoch 24/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1261 - mean_squared_error: 0.0188
# Epoch 25/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.1241 - mean_squared_error: 0.0183
# Epoch 26/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.1215 - mean_squared_error: 0.0177
# Epoch 27/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1230 - mean_squared_error: 0.0187
# Epoch 28/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1203 - mean_squared_error: 0.0176
# Epoch 29/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1198 - mean_squared_error: 0.0177
# Epoch 30/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1196 - mean_squared_error: 0.0178
# Epoch 31/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.1167 - mean_squared_error: 0.0170
# Epoch 32/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1164 - mean_squared_error: 0.0171
# Epoch 33/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.1146 - mean_squared_error: 0.0166
# Epoch 34/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1156 - mean_squared_error: 0.0171
# Epoch 35/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.1118 - mean_squared_error: 0.0160
# Epoch 36/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1120 - mean_squared_error: 0.0161
# Epoch 37/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1108 - mean_squared_error: 0.0160
# Epoch 38/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1094 - mean_squared_error: 0.0156
# Epoch 39/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1082 - mean_squared_error: 0.0154
# Epoch 40/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1071 - mean_squared_error: 0.0152
# Epoch 41/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1070 - mean_squared_error: 0.0153
# Epoch 42/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1045 - mean_squared_error: 0.0145
# Epoch 43/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1053 - mean_squared_error: 0.0150
# Epoch 44/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1073 - mean_squared_error: 0.0159
# Epoch 45/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1076 - mean_squared_error: 0.0160
# Epoch 46/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1023 - mean_squared_error: 0.0143
# Epoch 47/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.1022 - mean_squared_error: 0.0144
# Epoch 48/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.1006 - mean_squared_error: 0.0140
# Epoch 49/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0989 - mean_squared_error: 0.0135
# Epoch 50/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0993 - mean_squared_error: 0.0137
# Epoch 51/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0977 - mean_squared_error: 0.0132
# Epoch 52/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0964 - mean_squared_error: 0.0130
# Epoch 53/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0970 - mean_squared_error: 0.0132
# Epoch 54/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0945 - mean_squared_error: 0.0125
# Epoch 55/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0955 - mean_squared_error: 0.0130
# Epoch 56/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0940 - mean_squared_error: 0.0125
# Epoch 57/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0923 - mean_squared_error: 0.0120
# Epoch 58/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0907 - mean_squared_error: 0.0115
# Epoch 59/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0909 - mean_squared_error: 0.0117
# Epoch 60/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0910 - mean_squared_error: 0.0119
# Epoch 61/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0888 - mean_squared_error: 0.0111
# Epoch 62/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0872 - mean_squared_error: 0.0107
# Epoch 63/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0857 - mean_squared_error: 0.0103
# Epoch 64/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0861 - mean_squared_error: 0.0104
# Epoch 65/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0860 - mean_squared_error: 0.0105
# Epoch 66/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0838 - mean_squared_error: 0.0099
# Epoch 67/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0822 - mean_squared_error: 0.0094
# Epoch 68/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0816 - mean_squared_error: 0.0094
# Epoch 69/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0808 - mean_squared_error: 0.0092
# Epoch 70/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0813 - mean_squared_error: 0.0094
# Epoch 71/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0801 - mean_squared_error: 0.0091
# Epoch 72/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0796 - mean_squared_error: 0.0090
# Epoch 73/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0782 - mean_squared_error: 0.0087
# Epoch 74/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0792 - mean_squared_error: 0.0091
# Epoch 75/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0785 - mean_squared_error: 0.0088
# Epoch 76/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0785 - mean_squared_error: 0.0089
# Epoch 77/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0771 - mean_squared_error: 0.0086
# Epoch 78/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0762 - mean_squared_error: 0.0085
# Epoch 79/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0751 - mean_squared_error: 0.0082
# Epoch 80/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0754 - mean_squared_error: 0.0082
# training batch no 2
# Epoch 1/80
#  2/19 [==>...........................] - ETA: 3s - loss: 0.0976 - mean_squared_error: 0.0156WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0704s vs `on_train_batch_end` time: 0.1547s). Check your callbacks.
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0987 - mean_squared_error: 0.0159
# Epoch 2/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0929 - mean_squared_error: 0.0140
# Epoch 3/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.0933 - mean_squared_error: 0.0143
# Epoch 4/80
# 19/19 [==============================] - 4s 225ms/step - loss: 0.0895 - mean_squared_error: 0.0131
# Epoch 5/80
# 19/19 [==============================] - 4s 226ms/step - loss: 0.0877 - mean_squared_error: 0.0124
# Epoch 6/80
# 19/19 [==============================] - 4s 227ms/step - loss: 0.0851 - mean_squared_error: 0.0117
# Epoch 7/80
# 19/19 [==============================] - 4s 227ms/step - loss: 0.0850 - mean_squared_error: 0.0116
# Epoch 8/80
# 19/19 [==============================] - 4s 226ms/step - loss: 0.0836 - mean_squared_error: 0.0112
# Epoch 9/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.0814 - mean_squared_error: 0.0105
# Epoch 10/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0800 - mean_squared_error: 0.0103
# Epoch 11/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0771 - mean_squared_error: 0.0094
# Epoch 12/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0766 - mean_squared_error: 0.0094
# Epoch 13/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0750 - mean_squared_error: 0.0089
# Epoch 14/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0746 - mean_squared_error: 0.0088
# Epoch 15/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0750 - mean_squared_error: 0.0089
# Epoch 16/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0730 - mean_squared_error: 0.0085
# Epoch 17/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0719 - mean_squared_error: 0.0082
# Epoch 18/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0727 - mean_squared_error: 0.0084
# Epoch 19/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0720 - mean_squared_error: 0.0085
# Epoch 20/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0714 - mean_squared_error: 0.0084
# Epoch 21/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0703 - mean_squared_error: 0.0081
# Epoch 22/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0694 - mean_squared_error: 0.0078
# Epoch 23/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0680 - mean_squared_error: 0.0075
# Epoch 24/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0671 - mean_squared_error: 0.0074
# Epoch 25/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0672 - mean_squared_error: 0.0075
# Epoch 26/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0666 - mean_squared_error: 0.0073
# Epoch 27/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0660 - mean_squared_error: 0.0071
# Epoch 28/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0660 - mean_squared_error: 0.0072
# Epoch 29/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0673 - mean_squared_error: 0.0078
# Epoch 30/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0662 - mean_squared_error: 0.0074
# Epoch 31/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0649 - mean_squared_error: 0.0071
# Epoch 32/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0641 - mean_squared_error: 0.0069
# Epoch 33/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0634 - mean_squared_error: 0.0068
# Epoch 34/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0630 - mean_squared_error: 0.0067
# Epoch 35/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0628 - mean_squared_error: 0.0068
# Epoch 36/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0620 - mean_squared_error: 0.0065
# Epoch 37/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0613 - mean_squared_error: 0.0065
# Epoch 38/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0607 - mean_squared_error: 0.0063
# Epoch 39/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0602 - mean_squared_error: 0.0063
# Epoch 40/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0596 - mean_squared_error: 0.0062
# Epoch 41/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0592 - mean_squared_error: 0.0062
# Epoch 42/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0590 - mean_squared_error: 0.0062
# Epoch 43/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0600 - mean_squared_error: 0.0064
# Epoch 44/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0597 - mean_squared_error: 0.0064
# Epoch 45/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0602 - mean_squared_error: 0.0065
# Epoch 46/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0626 - mean_squared_error: 0.0069
# Epoch 47/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0619 - mean_squared_error: 0.0068
# Epoch 48/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0597 - mean_squared_error: 0.0065
# Epoch 49/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0585 - mean_squared_error: 0.0061
# Epoch 50/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0572 - mean_squared_error: 0.0059
# Epoch 51/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0567 - mean_squared_error: 0.0058
# Epoch 52/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0568 - mean_squared_error: 0.0059
# Epoch 53/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0569 - mean_squared_error: 0.0060
# Epoch 54/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0570 - mean_squared_error: 0.0060
# Epoch 55/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0567 - mean_squared_error: 0.0059
# Epoch 56/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0563 - mean_squared_error: 0.0059
# Epoch 57/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0568 - mean_squared_error: 0.0061
# Epoch 58/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0560 - mean_squared_error: 0.0058
# Epoch 59/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0555 - mean_squared_error: 0.0058
# Epoch 60/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0562 - mean_squared_error: 0.0060
# Epoch 61/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0562 - mean_squared_error: 0.0061
# Epoch 62/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0569 - mean_squared_error: 0.0062
# Epoch 63/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0557 - mean_squared_error: 0.0059
# Epoch 64/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0553 - mean_squared_error: 0.0058
# Epoch 65/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0551 - mean_squared_error: 0.0058
# Epoch 66/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0543 - mean_squared_error: 0.0057
# Epoch 67/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0537 - mean_squared_error: 0.0055
# Epoch 68/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0533 - mean_squared_error: 0.0054
# Epoch 69/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0532 - mean_squared_error: 0.0054
# Epoch 70/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0531 - mean_squared_error: 0.0054
# Epoch 71/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0535 - mean_squared_error: 0.0054
# Epoch 72/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0533 - mean_squared_error: 0.0054
# Epoch 73/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0526 - mean_squared_error: 0.0053
# Epoch 74/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0526 - mean_squared_error: 0.0053
# Epoch 75/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0522 - mean_squared_error: 0.0053
# Epoch 76/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0521 - mean_squared_error: 0.0053
# Epoch 77/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0523 - mean_squared_error: 0.0054
# Epoch 78/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0525 - mean_squared_error: 0.0054
# Epoch 79/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0531 - mean_squared_error: 0.0053
# Epoch 80/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0531 - mean_squared_error: 0.0056
# training batch no 3
# Epoch 1/80
#  2/18 [==>...........................] - ETA: 3s - loss: 0.0773 - mean_squared_error: 0.0123WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0688s vs `on_train_batch_end` time: 0.1502s). Check your callbacks.
# 18/18 [==============================] - 6s 358ms/step - loss: 0.0816 - mean_squared_error: 0.0135
# Epoch 2/80
# 18/18 [==============================] - 4s 218ms/step - loss: 0.0789 - mean_squared_error: 0.0128
# Epoch 3/80
# 18/18 [==============================] - 4s 219ms/step - loss: 0.0735 - mean_squared_error: 0.0110
# Epoch 4/80
# 18/18 [==============================] - 4s 219ms/step - loss: 0.0708 - mean_squared_error: 0.0103
# Epoch 5/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0706 - mean_squared_error: 0.0101
# Epoch 6/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0645 - mean_squared_error: 0.0083
# Epoch 7/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0615 - mean_squared_error: 0.0075
# Epoch 8/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0601 - mean_squared_error: 0.0071
# Epoch 9/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0595 - mean_squared_error: 0.0070
# Epoch 10/80
# 18/18 [==============================] - 4s 226ms/step - loss: 0.0580 - mean_squared_error: 0.0065
# Epoch 11/80
# 18/18 [==============================] - 4s 226ms/step - loss: 0.0557 - mean_squared_error: 0.0061
# Epoch 12/80
# 18/18 [==============================] - 4s 227ms/step - loss: 0.0544 - mean_squared_error: 0.0058
# Epoch 13/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0533 - mean_squared_error: 0.0055
# Epoch 14/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0523 - mean_squared_error: 0.0053
# Epoch 15/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0522 - mean_squared_error: 0.0054
# Epoch 16/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0520 - mean_squared_error: 0.0053
# Epoch 17/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0513 - mean_squared_error: 0.0051
# Epoch 18/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0527 - mean_squared_error: 0.0056
# Epoch 19/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0534 - mean_squared_error: 0.0057
# Epoch 20/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0520 - mean_squared_error: 0.0053
# Epoch 21/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0505 - mean_squared_error: 0.0050
# Epoch 22/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0498 - mean_squared_error: 0.0048
# Epoch 23/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0490 - mean_squared_error: 0.0047
# Epoch 24/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0485 - mean_squared_error: 0.0046
# Epoch 25/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0484 - mean_squared_error: 0.0045
# Epoch 26/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0484 - mean_squared_error: 0.0045
# Epoch 27/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0481 - mean_squared_error: 0.0045
# Epoch 28/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0479 - mean_squared_error: 0.0044
# Epoch 29/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0480 - mean_squared_error: 0.0045
# Epoch 30/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0482 - mean_squared_error: 0.0045
# Epoch 31/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0480 - mean_squared_error: 0.0046
# Epoch 32/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0484 - mean_squared_error: 0.0046
# Epoch 33/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0479 - mean_squared_error: 0.0045
# Epoch 34/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0476 - mean_squared_error: 0.0045
# Epoch 35/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0473 - mean_squared_error: 0.0044
# Epoch 36/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0470 - mean_squared_error: 0.0043
# Epoch 37/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0467 - mean_squared_error: 0.0043
# Epoch 38/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0467 - mean_squared_error: 0.0043
# Epoch 39/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0465 - mean_squared_error: 0.0043
# Epoch 40/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0468 - mean_squared_error: 0.0044
# Epoch 41/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0494 - mean_squared_error: 0.0051
# Epoch 42/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0491 - mean_squared_error: 0.0050
# Epoch 43/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0479 - mean_squared_error: 0.0046
# Epoch 44/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0474 - mean_squared_error: 0.0045
# Epoch 45/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0476 - mean_squared_error: 0.0044
# Epoch 46/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0475 - mean_squared_error: 0.0045
# Epoch 47/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0476 - mean_squared_error: 0.0045
# Epoch 48/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0474 - mean_squared_error: 0.0045
# Epoch 49/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0464 - mean_squared_error: 0.0043
# Epoch 50/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0463 - mean_squared_error: 0.0044
# Epoch 51/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0460 - mean_squared_error: 0.0043
# Epoch 52/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0461 - mean_squared_error: 0.0043
# Epoch 53/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0458 - mean_squared_error: 0.0042
# Epoch 54/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0461 - mean_squared_error: 0.0043
# Epoch 55/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0462 - mean_squared_error: 0.0042
# Epoch 56/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0460 - mean_squared_error: 0.0043
# Epoch 57/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0461 - mean_squared_error: 0.0043
# Epoch 58/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0455 - mean_squared_error: 0.0041
# Epoch 59/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0449 - mean_squared_error: 0.0041
# Epoch 60/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0447 - mean_squared_error: 0.0040
# Epoch 61/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0446 - mean_squared_error: 0.0041
# Epoch 62/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0448 - mean_squared_error: 0.0041
# Epoch 63/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0454 - mean_squared_error: 0.0042
# Epoch 64/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0455 - mean_squared_error: 0.0043
# Epoch 65/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0456 - mean_squared_error: 0.0043
# Epoch 66/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0467 - mean_squared_error: 0.0045
# Epoch 67/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0462 - mean_squared_error: 0.0044
# Epoch 68/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0463 - mean_squared_error: 0.0045
# Epoch 69/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0451 - mean_squared_error: 0.0042
# Epoch 70/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0444 - mean_squared_error: 0.0040
# Epoch 71/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0440 - mean_squared_error: 0.0039
# Epoch 72/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0440 - mean_squared_error: 0.0040
# Epoch 73/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0450 - mean_squared_error: 0.0043
# Epoch 74/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0454 - mean_squared_error: 0.0043
# Epoch 75/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0454 - mean_squared_error: 0.0043
# Epoch 76/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0449 - mean_squared_error: 0.0042
# Epoch 77/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0447 - mean_squared_error: 0.0042
# Epoch 78/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0442 - mean_squared_error: 0.0040
# Epoch 79/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0439 - mean_squared_error: 0.0039
# Epoch 80/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0434 - mean_squared_error: 0.0039

# %%
def get_result(image ,plot = True):

    image = image.reshape((-1,256,256 ,3))
    image_ = ((image/255.0))
    raw_result = model.predict(image_)
    result = raw_result.reshape((128,128,3))
    result = 255*((result))
    if plot:
        cv2_imshow(image.reshape((128,128,3)))
        cv2_imshow(result)
    return result

# %%
model.save('/content/gdrive/My Drive/weights.h5')

# %%
sett =('/content/gdrive/My Drive/rod2.jpg')

# %%
image = os.listdir(test_input_dir)
img =  random.choice(image)
img_dir = test_input_dir + '/' +img
img_dir_ = test_output_dir + '/' +img
img_dire = sett 
image = cv2.resize(cv2.imread(img_dir),(256,256))
image_ = cv2.resize(cv2.imread(img_dir_),(256,256))
image__ = cv2.resize(cv2.imread(img_dire),(256,256))
result = get_result(image ,plot = False)
result1 = get_result(image__ ,plot = False)
result = cv2.resize(result,(256,256))
result1 = cv2.resize(result1,(256,256))
print("input")
cv2_imshow(image)
print("output")
cv2_imshow(image_)
print("predicted op")
cv2_imshow(result)
print("AUV input")
cv2_imshow(image__)
# Out:
# input
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481FEA080>
# output
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481FEA208>
# predicted op
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481FEA160>
# AUV input
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481FEA080>

# %%
print("predicted AUV output")
cv2_imshow(result1)
# Out:
# predicted AUV output
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24D0027C50>

# %%
video1 = '/content/gdrive/My Drive/redrodtrim.mp4'

# %%
from google.colab.patches import cv2_imshow
import cv2

cap = cv2.VideoCapture(video1)
while cap.isOpened():
    ret, image = cap.read()
    image = cv2.resize(image,(256,256))
    cv2_imshow(image) # Note cv2_imshow, not cv2.imshow
    result = get_result(image ,plot = False)
    result = cv2.resize(result,(256,256))
    cv2_imshow(result)
    cv2.waitKey(1)

cv2.destroyAllWindows()
cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2488683358>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2488683390>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2488683358>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6AF98>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A6D8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A588>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F248070BEB8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A588>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A6D8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A6D8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2481F6A588>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480705470>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480705710>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24806CACC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480705470>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480705470>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480705470>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F2480730E48>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24807057B8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24807057B8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24807057B8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F24807057B8>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-24-cc7e2bf67b88> in <module>()
#       5 while cap.isOpened():
#       6     ret, image = cap.read()
# ----> 7     image = cv2.resize(image,(256,256))
#       8     cv2_imshow(image) # Note cv2_imshow, not cv2.imshow
#       9     result = get_result(image ,plot = False)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
