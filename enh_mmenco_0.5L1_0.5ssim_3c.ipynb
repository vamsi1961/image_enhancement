# %%
import tensorflow
import keras
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Dense ,Conv2D ,Conv2DTranspose ,Dropout ,BatchNormalization ,Input ,MaxPooling2D ,concatenate
import numpy as np
import cv2
import matplotlib.pyplot as plt
from tensorflow.keras.models import Model
from google.colab import drive
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import random
import os
from tensorflow.keras.optimizers import Adam
from google.colab.patches import cv2_imshow

# %%
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
train_input_dir = '/content/gdrive/My Drive/train_input_870'
train_output_dir = '/content/gdrive/My Drive/train_output_870'
test_input_dir = '/content/gdrive/My Drive/test_input_20'
test_output_dir = '/content/gdrive/My Drive/test_output_20'

# %%
def images(dir_train,dir_test):
  images = os.listdir(dir_train)
  images_ = os.listdir(dir_test)
  k = random.choice(images)
  k_ = random.choice(images_)
  file_train = dir_train + '/' + k
  file_test = dir_test + '/' + k_
  print(len(images))
  print(len(images_))
  img = cv2.resize(cv2.imread(file_train),(256,256))
  img_ = cv2.resize(cv2.imread(file_test),(256,256))
  cv2_imshow(img)
  cv2_imshow(img_)

# %%
images(train_input_dir,train_output_dir)
# Out:
# 885
# 885
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8248041BE0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229FF22E8>

# %%
def conv_model(hidden_size):
    input_layer = Input((256,256,3))
    conv_1 = Conv2D(hidden_size * 1,(3,3),activation = "relu" ,padding = "same")(input_layer)
    conv_1 = Conv2D(hidden_size * 1,(3,3),activation = "relu" ,padding = "same")(conv_1)
    conv_1 = Conv2D(hidden_size * 1,(1,1),activation = "relu" ,strides=(2,2))(conv_1)


    conv_2 = Conv2D(hidden_size * 2,(3,3),activation = "relu" ,padding = "same")(conv_1)
    conv_2 = Conv2D(hidden_size * 2,(3,3),activation = "relu" ,padding = "same")(conv_2)
    conv_2 = Conv2D(hidden_size * 2,(1,1),activation = "relu" ,strides=(2,2))(conv_2)

    conv_3 = Conv2D(hidden_size * 4,(3,3),activation = "relu" ,padding = "same")(conv_2)
    conv_3 = Conv2D(hidden_size * 4,(3,3),activation = "relu" ,padding = "same")(conv_3)
    conv_3 = Conv2D(hidden_size * 4,(1,1),activation = "relu" ,strides=(2,2))(conv_3)

    conv_4 = Conv2D(hidden_size * 8,(3,3),activation = "relu" ,padding = "same")(conv_3)
    conv_4 = Conv2D(hidden_size * 8,(3,3),activation = "relu" ,padding = "same")(conv_4)
    conv_4 = Conv2D(hidden_size * 8,(1,1),activation = "relu" ,strides=(2,2))(conv_4)

    conv_5 = Conv2D(hidden_size * 16,(3,3),activation = "relu" ,padding = "same")(conv_4)
    conv_5 = Conv2D(hidden_size * 16,(3,3),activation = "relu" ,padding = "same")(conv_5)
    conv_5 = Conv2D(hidden_size * 16,(1,1),activation = "relu" ,strides=(2,2))(conv_5)   

    conv_m = Conv2D(hidden_size * 32,(3,3),activation = "relu" ,padding = "same")(conv_5)
    conv_m = Conv2D(hidden_size * 32,(3,3),activation = "relu" ,padding = "same")(conv_m)
    conv_m = Conv2D(hidden_size * 32,(1,1),activation = "relu" ,strides=(2,2))(conv_m)

    de_conv_5 = Conv2DTranspose(hidden_size * 16, (3, 3), strides=(2, 2), padding="same")(conv_m)
    de_conv_5 = concatenate([de_conv_5 , conv_5])
    de_conv_5 = Conv2D(hidden_size * 16, (3, 3), activation="relu", padding="same")(de_conv_5)
    de_conv_5 = Conv2D(hidden_size * 16, (3, 3), activation="relu", padding="same")(de_conv_5)


    de_conv_4 = Conv2DTranspose(hidden_size * 8, (3, 3), strides=(2, 2), padding="same")(de_conv_5)
    de_conv_4 = concatenate([de_conv_4 , conv_4])
    de_conv_4 = Conv2D(hidden_size * 8, (3, 3), activation="relu", padding="same")(de_conv_4)
    de_conv_4 = Conv2D(hidden_size * 8, (3, 3), activation="relu", padding="same")(de_conv_4)

    de_conv_3 = Conv2DTranspose(hidden_size * 4, (3, 3), strides=(2, 2), padding="same")(de_conv_4)
    de_conv_3 = concatenate([de_conv_3 , conv_3])
    de_conv_3 = Conv2D(hidden_size * 4, (3, 3), activation="relu", padding="same")(de_conv_3)
    de_conv_3 = Conv2D(hidden_size * 4 ,(3, 3), activation="relu", padding="same")(de_conv_3)

    de_conv_2 = Conv2DTranspose(hidden_size * 2, (3, 3), strides=(2, 2), padding="same")(de_conv_3)
    de_conv_2 = concatenate([de_conv_2 , conv_2])
    de_conv_2 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_2)
    de_conv_2 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_2)

    de_conv_1 = Conv2DTranspose(hidden_size * 2, (3, 3), strides=(2, 2), padding="same")(de_conv_2)
    #de_conv_1 = concatenate([de_conv_1 , conv_1])
    de_conv_1 = Conv2D(hidden_size * 2, (3, 3), activation="relu", padding="same")(de_conv_1)
    de_conv_1 = Conv2D(hidden_size * 2 ,(3, 3), activation="relu", padding="same")(de_conv_1)

    output_layer = Conv2D(3, (1,1), padding="same", activation="sigmoid")(de_conv_1)

    model = Model(inputs = [input_layer] ,outputs = [output_layer])
    return model


model = conv_model(32)

# %%
model.summary()
# Out:
# Model: "functional_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 32) 896         input_2[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 256, 256, 32) 9248        conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 128, 128, 32) 1056        conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 128, 128, 64) 18496       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 64, 64, 64)   4160        conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 128)  73856       conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 64, 64, 128)  147584      conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 32, 32, 128)  16512       conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 32, 32, 256)  295168      conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 32, 32, 256)  590080      conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 16, 16, 256)  65792       conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 16, 16, 512)  1180160     conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 16, 16, 512)  2359808     conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 8, 8, 512)    262656      conv2d_42[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 8, 8, 1024)   4719616     conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 8, 8, 1024)   9438208     conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 4, 4, 1024)   1049600     conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 8, 8, 512)    4719104     conv2d_46[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 8, 8, 1024)   0           conv2d_transpose_5[0][0]
#                                                                  conv2d_43[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 8, 8, 512)    4719104     concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_48 (Conv2D)              (None, 8, 8, 512)    2359808     conv2d_47[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 16, 16, 256)  1179904     conv2d_48[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 512)  0           conv2d_transpose_6[0][0]
#                                                                  conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_49 (Conv2D)              (None, 16, 16, 256)  1179904     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_50 (Conv2D)              (None, 16, 16, 256)  590080      conv2d_49[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 32, 32, 128)  295040      conv2d_50[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 256)  0           conv2d_transpose_7[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_51 (Conv2D)              (None, 32, 32, 128)  295040      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_52 (Conv2D)              (None, 32, 32, 128)  147584      conv2d_51[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 64, 64, 64)   73792       conv2d_52[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 128)  0           conv2d_transpose_8[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_53 (Conv2D)              (None, 64, 64, 64)   73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_54 (Conv2D)              (None, 64, 64, 64)   36928       conv2d_53[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 128, 128, 64) 36928       conv2d_54[0][0]
# __________________________________________________________________________________________________
# conv2d_55 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_transpose_9[0][0]
# __________________________________________________________________________________________________
# conv2d_56 (Conv2D)              (None, 128, 128, 64) 36928       conv2d_55[0][0]
# __________________________________________________________________________________________________
# conv2d_57 (Conv2D)              (None, 128, 128, 3)  195         conv2d_56[0][0]
# ==================================================================================================
# Total params: 36,050,883
# Trainable params: 36,050,883
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import tensorflow as tf
def loss_fn(y_true,y_pred):
    mae = tf.keras.losses.MeanAbsoluteError()
    k = mae(y_true, y_pred)
    k = (k/(256*256))
    ssim = tf.image.ssim(y_true *255 , y_pred * 255, max_val = 255, filter_size=11, filter_sigma=1.5, k1=0.01, k2=0.03)
    m = (1-ssim)/2
    return ((0.5*k) + (0.5*m))
model.compile(optimizer = Adam(lr = 0.0001),loss = loss_fn ,metrics = [tf.keras.metrics.MeanSquaredError()])

# %%
def load_file(fname ,path_input,path_output):
  image  = path_input + '/' + fname
  image_ = path_output + '/' + fname
  img = cv2.imread(image)
  img_ = cv2.imread(image_)
  img = cv2.resize(img,(256,256))
  img_ = cv2.resize(img_,(128,128))
  return(img,img_)

# %%
def data_generator(path_train,path_test,batch_size_):

  fnames_train = os.listdir(path_train)
  fnames_test = os.listdir(path_test)

  random.shuffle(fnames_train)
  random.shuffle(fnames_test)

  print(len(fnames_train))
  print(len(fnames_test))

  no_of_batches = len(fnames_train)//batch_size_

  for i in range(no_of_batches+1):
    X_train = []
    Y_train = []
    print('training batch no {}'.format(i+1))
    try:
      present_train = fnames_train[i*batch_size_:(i+1)*batch_size_]
      present_test  = fnames_test[i*batch_size_:(i+1)*batch_size_]
    except:
      present_train = fnames_train[i*batch_size_:]
      present_test  = fnames_test[i*batch_size_:]
      
    for name_train in present_train: 
      tup_train = load_file(name_train,path_train,path_test)
      X_train.append(tup_train[0])
      Y_train.append(tup_train[1])

    X_train = (np.asarray(X_train)/255.0)
    Y_train = (np.asarray(Y_train)/255.0)

    history = model.fit(X_train,Y_train,batch_size = 16 ,epochs = 80 ,verbose = 1,shuffle = True)

  return history

# %%
history = data_generator(train_input_dir,train_output_dir ,batch_size_ = 300)
# Out:
# 885
# 885
# training batch no 1
# Epoch 1/80
#  2/19 [==>...........................] - ETA: 1s - loss: 0.2005 - mean_squared_error: 0.0668WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0770s vs `on_train_batch_end` time: 0.1378s). Check your callbacks.
# 19/19 [==============================] - 6s 321ms/step - loss: 0.1967 - mean_squared_error: 0.0668
# Epoch 2/80
# 19/19 [==============================] - 4s 205ms/step - loss: 0.1958 - mean_squared_error: 0.0660
# Epoch 3/80
# 19/19 [==============================] - 4s 205ms/step - loss: 0.1831 - mean_squared_error: 0.0670
# Epoch 4/80
# 19/19 [==============================] - 4s 206ms/step - loss: 0.1467 - mean_squared_error: 0.0694
# Epoch 5/80
# 19/19 [==============================] - 4s 207ms/step - loss: 0.1295 - mean_squared_error: 0.0533
# Epoch 6/80
# 19/19 [==============================] - 4s 208ms/step - loss: 0.1171 - mean_squared_error: 0.0400
# Epoch 7/80
# 19/19 [==============================] - 4s 209ms/step - loss: 0.1088 - mean_squared_error: 0.0341
# Epoch 8/80
# 19/19 [==============================] - 4s 210ms/step - loss: 0.1035 - mean_squared_error: 0.0325
# Epoch 9/80
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0994 - mean_squared_error: 0.0313
# Epoch 10/80
# 19/19 [==============================] - 4s 211ms/step - loss: 0.0958 - mean_squared_error: 0.0298
# Epoch 11/80
# 19/19 [==============================] - 4s 211ms/step - loss: 0.0948 - mean_squared_error: 0.0320
# Epoch 12/80
# 19/19 [==============================] - 4s 211ms/step - loss: 0.0916 - mean_squared_error: 0.0293
# Epoch 13/80
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0894 - mean_squared_error: 0.0284
# Epoch 14/80
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0887 - mean_squared_error: 0.0298
# Epoch 15/80
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0871 - mean_squared_error: 0.0294
# Epoch 16/80
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0850 - mean_squared_error: 0.0275
# Epoch 17/80
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0834 - mean_squared_error: 0.0266
# Epoch 18/80
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0819 - mean_squared_error: 0.0262
# Epoch 19/80
# 19/19 [==============================] - 4s 215ms/step - loss: 0.0810 - mean_squared_error: 0.0261
# Epoch 20/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0798 - mean_squared_error: 0.0260
# Epoch 21/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0789 - mean_squared_error: 0.0258
# Epoch 22/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0775 - mean_squared_error: 0.0251
# Epoch 23/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0762 - mean_squared_error: 0.0245
# Epoch 24/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0759 - mean_squared_error: 0.0249
# Epoch 25/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0745 - mean_squared_error: 0.0238
# Epoch 26/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0742 - mean_squared_error: 0.0239
# Epoch 27/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0733 - mean_squared_error: 0.0236
# Epoch 28/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.
ARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0682s vs `on_train_batch_end` time: 0.1424s). Check your callbacks.
# 19/19 [==============================] - 4s 211ms/step - loss: 0.0536 - mean_squared_error: 0.0161
# Epoch 2/80
# 19/19 [==============================] - 4s 209ms/step - loss: 0.0517 - mean_squared_error: 0.0148
# Epoch 3/80
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0507 - mean_squared_error: 0.0139
# Epoch 4/80
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0503 - mean_squared_error: 0.0141
# Epoch 5/80
# 19/19 [==============================] - 4s 210ms/step - loss: 0.0489 - mean_squared_error: 0.0130
# Epoch 6/80
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0476 - mean_squared_error: 0.0126
# Epoch 7/80
# 19/19 [==============================] - 4s 212ms/step - loss: 0.0481 - mean_squared_error: 0.0131
# Epoch 8/80
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0477 - mean_squared_error: 0.0123
# Epoch 9/80
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0461 - mean_squared_error: 0.0112
# Epoch 10/80
# 19/19 [==============================] - 4s 213ms/step - loss: 0.0451 - mean_squared_error: 0.0107
# Epoch 11/80
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0454 - mean_squared_error: 0.0111
# Epoch 12/80
# 19/19 [==============================] - 4s 214ms/step - loss: 0.0449 - mean_squared_error: 0.0107
# Epoch 13/80
# 19/19 [==============================] - 4s 215ms/step - loss: 0.0460 - mean_squared_error: 0.0106
# Epoch 14/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0434 - mean_squared_error: 0.0099
# Epoch 15/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0426 - mean_squared_error: 0.0094
# Epoch 16/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0424 - mean_squared_error: 0.0096
# Epoch 17/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0419 - mean_squared_error: 0.0093
# Epoch 18/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0418 - mean_squared_error: 0.0090
# Epoch 19/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0415 - mean_squared_error: 0.0090
# Epoch 20/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0409 - mean_squared_error: 0.0090
# Epoch 21/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0408 - mean_squared_error: 0.0086
# Epoch 22/80
# 19/19 [==============================] - 4s 216ms/step - loss: 0.0399 - mean_squared_error: 0.0084
# Epoch 23/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0402 - mean_squared_error: 0.0087
# Epoch 24/80
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0393 - mean_squared_error: 0.0080
# Epoch 25/80
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0387 - mean_squared_error: 0.0079
# Epoch 26/80
# 19/19 [==============================] - 4s 217ms/step - loss: 0.0385 - mean_squared_error: 0.0077
# Epoch 27/80
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0379 - mean_squared_error: 0.0075
# Epoch 28/80
# 19/19 [==============================] - 4s 218ms/step - loss: 0.0376 - mean_squared_error: 0.0072
# Epoch 29/80
# 19/19 [==============================] - 4s 219ms/step - loss: 0.0374 - mean_squared_error: 0.0070
# Epoch 30/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0372 - mean_squared_error: 0.0069
# Epoch 31/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0369 - mean_squared_error: 0.0069
# Epoch 32/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0369 - mean_squared_error: 0.0069
# Epoch 33/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0368 - mean_squared_error: 0.0070
# Epoch 34/80
# 19/19 [==============================] - 4s 220ms/step - loss: 0.0366 - mean_squared_error: 0.0068
# Epoch 35/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0365 - mean_squared_error: 0.0069
# Epoch 36/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0364 - mean_squared_error: 0.0067
# Epoch 37/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0365 - mean_squared_error: 0.0068
# Epoch 38/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0366 - mean_squared_error: 0.0070
# Epoch 39/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0360 - mean_squared_error: 0.0067
# Epoch 40/80
# 19/19 [==============================] - 4s 221ms/step - loss: 0.0358 - mean_squared_error: 0.0066
# Epoch 41/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0354 - mean_squared_error: 0.0064
# Epoch 42/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0352 - mean_squared_error: 0.0063
# Epoch 43/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0349 - mean_squared_error: 0.0062
# Epoch 44/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0349 - mean_squared_error: 0.0061
# Epoch 45/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0352 - mean_squared_error: 0.0063
# Epoch 46/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0360 - mean_squared_error: 0.0065
# Epoch 47/80
# 19/19 [==============================] - 4s 222ms/step - loss: 0.0353 - mean_squared_error: 0.0063
# Epoch 48/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0355 - mean_squared_error: 0.0065
# Epoch 49/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0353 - mean_squared_error: 0.0062
# Epoch 50/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0346 - mean_squared_error: 0.0062
# Epoch 51/80
# 19/19 [==============================] - 4s 223ms/step - loss: 0.0349 - mean_squared_error: 0.0061
# Epoch 52/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.0344 - mean_squared_error: 0.0061
# Epoch 53/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.0343 - mean_squared_error: 0.0061
# Epoch 54/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.0343 - mean_squared_error: 0.0061
# Epoch 55/80
# 19/19 [==============================] - 4s 224ms/step - loss: 0.
80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0353 - mean_squared_error: 0.0065
# Epoch 17/80
# 18/18 [==============================] - 4s 216ms/step - loss: 0.0352 - mean_squared_error: 0.0064
# Epoch 18/80
# 18/18 [==============================] - 4s 216ms/step - loss: 0.0351 - mean_squared_error: 0.0064
# Epoch 19/80
# 18/18 [==============================] - 4s 216ms/step - loss: 0.0347 - mean_squared_error: 0.0062
# Epoch 20/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0346 - mean_squared_error: 0.0062
# Epoch 21/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0349 - mean_squared_error: 0.0062
# Epoch 22/80
# 18/18 [==============================] - 4s 218ms/step - loss: 0.0345 - mean_squared_error: 0.0062
# Epoch 23/80
# 18/18 [==============================] - 4s 218ms/step - loss: 0.0348 - mean_squared_error: 0.0064
# Epoch 24/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0348 - mean_squared_error: 0.0064
# Epoch 25/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0347 - mean_squared_error: 0.0063
# Epoch 26/80
# 18/18 [==============================] - 4s 218ms/step - loss: 0.0347 - mean_squared_error: 0.0063
# Epoch 27/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0341 - mean_squared_error: 0.0060
# Epoch 28/80
# 18/18 [==============================] - 4s 217ms/step - loss: 0.0339 - mean_squared_error: 0.0060
# Epoch 29/80
# 18/18 [==============================] - 4s 218ms/step - loss: 0.0336 - mean_squared_error: 0.0059
# Epoch 30/80
# 18/18 [==============================] - 4s 219ms/step - loss: 0.0333 - mean_squared_error: 0.0057
# Epoch 31/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0331 - mean_squared_error: 0.0057
# Epoch 32/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0330 - mean_squared_error: 0.0056
# Epoch 33/80
# 18/18 [==============================] - 4s 219ms/step - loss: 0.0331 - mean_squared_error: 0.0057
# Epoch 34/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0331 - mean_squared_error: 0.0057
# Epoch 35/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0332 - mean_squared_error: 0.0057
# Epoch 36/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0330 - mean_squared_error: 0.0057
# Epoch 37/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0337 - mean_squared_error: 0.0059
# Epoch 38/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0337 - mean_squared_error: 0.0061
# Epoch 39/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0333 - mean_squared_error: 0.0058
# Epoch 40/80
# 18/18 [==============================] - 4s 220ms/step - loss: 0.0330 - mean_squared_error: 0.0056
# Epoch 41/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0327 - mean_squared_error: 0.0055
# Epoch 42/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0325 - mean_squared_error: 0.0055
# Epoch 43/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0322 - mean_squared_error: 0.0054
# Epoch 44/80
# 18/18 [==============================] - 4s 221ms/step - loss: 0.0321 - mean_squared_error: 0.0053
# Epoch 45/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0321 - mean_squared_error: 0.0053
# Epoch 46/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0321 - mean_squared_error: 0.0053
# Epoch 47/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0329 - mean_squared_error: 0.0054
# Epoch 48/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0334 - mean_squared_error: 0.0057
# Epoch 49/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0326 - mean_squared_error: 0.0055
# Epoch 50/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0330 - mean_squared_error: 0.0056
# Epoch 51/80
# 18/18 [==============================] - 4s 222ms/step - loss: 0.0324 - mean_squared_error: 0.0055
# Epoch 52/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0323 - mean_squared_error: 0.0055
# Epoch 53/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0322 - mean_squared_error: 0.0055
# Epoch 54/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0320 - mean_squared_error: 0.0053
# Epoch 55/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0319 - mean_squared_error: 0.0054
# Epoch 56/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0320 - mean_squared_error: 0.0053
# Epoch 57/80
# 18/18 [==============================] - 4s 223ms/step - loss: 0.0320 - mean_squared_error: 0.0053
# Epoch 58/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0320 - mean_squared_error: 0.0053
# Epoch 59/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0317 - mean_squared_error: 0.0053
# Epoch 60/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0318 - mean_squared_error: 0.0053
# Epoch 61/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0317 - mean_squared_error: 0.0053
# Epoch 62/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0317 - mean_squared_error: 0.0053
# Epoch 63/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0317 - mean_squared_error: 0.0053
# Epoch 64/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0318 - mean_squared_error: 0.0053
# Epoch 65/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0319 - mean_squared_error: 0.0054
# Epoch 66/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0319 - mean_squared_error: 0.0054
# Epoch 67/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0317 - mean_squared_error: 0.0054
# Epoch 68/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0316 - mean_squared_error: 0.0053
# Epoch 69/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0315 - mean_squared_error: 0.0052
# Epoch 70/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0314 - mean_squared_error: 0.0052
# Epoch 71/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0314 - mean_squared_error: 0.0052
# Epoch 72/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0314 - mean_squared_error: 0.0052
# Epoch 73/80
# 18/18 [==============================] - 4s 225ms/step - loss: 0.0313 - mean_squared_error: 0.0052
# Epoch 74/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0312 - mean_squared_error: 0.0052
# Epoch 75/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0313 - mean_squared_error: 0.0052
# Epoch 76/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0314 - mean_squared_error: 0.0053
# Epoch 77/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0314 - mean_squared_error: 0.0053
# Epoch 78/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0316 - mean_squared_error: 0.0052
# Epoch 79/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0317 - mean_squared_error: 0.0053
# Epoch 80/80
# 18/18 [==============================] - 4s 224ms/step - loss: 0.0318 - mean_squared_error: 0.0053

# %%
def get_result(image ,plot = True):

    image = image.reshape((-1,256,256 ,3))
    image_ = ((image/255.0))
    raw_result = model.predict(image_)
    result = raw_result.reshape((128,128,3))
    result = 255*((result))
    if plot:
        cv2_imshow(image.reshape((128,128,3)))
        cv2_imshow(result)
    return result

# %%
model.save('/content/gdrive/My Drive/weights.h5')

# %%
sett =('/content/gdrive/My Drive/rod2.jpg')

# %%
image = os.listdir(test_input_dir)
img =  random.choice(image)
img_dir = test_input_dir + '/' +img
img_dir_ = test_output_dir + '/' +img
img_dire = sett 
image = cv2.resize(cv2.imread(img_dir),(256,256))
image_ = cv2.resize(cv2.imread(img_dir_),(256,256))
image__ = cv2.resize(cv2.imread(img_dire),(256,256))
result = get_result(image ,plot = False)
result1 = get_result(image__ ,plot = False)
result = cv2.resize(result,(256,256))
result1 = cv2.resize(result1,(256,256))
print("test_input")
cv2_imshow(image)
print("test_output")
cv2_imshow(image_)
print("predicted_op")
cv2_imshow(result)
print("AUV input")
cv2_imshow(image__)
# Out:
# test_input
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229D69978>
# test_output
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229D69898>
# predicted_op
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229D69898>
# AUV input
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229D69898>

# %%
print("predicted AUV output")
cv2_imshow(result1)
# Out:
# predicted AUV output
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F824064D240>

# %%
video1 = '/content/gdrive/My Drive/redrodtrim.mp4'

# %%
image2 = '/content/gdrive/My Drive/rod-3.PNG'

# %%
image1 = cv2.resize(cv2.imread(image2),(256,256))
result = get_result(image1 ,plot = False)
result = cv2.resize(result,(256,256))
cv2_imshow(image1)
cv2_imshow(result)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85C50>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85E10>

# %%
from google.colab.patches import cv2_imshow
import cv2

cap = cv2.VideoCapture(video1)
while cap.isOpened():
    ret, image = cap.read()
    image = cv2.resize(image,(256,256))
    cv2_imshow(image) # Note cv2_imshow, not cv2.imshow
    result = get_result(image ,plot = False)
    result = cv2.resize(result,(256,256))
    cv2_imshow(result)
    cv2.waitKey(1)

cv2.destroyAllWindows()
cap.release()
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEECC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEECC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEED68>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEE7F0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEE7F0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FED1D0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEECC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEED68>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FC8CC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85550>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FEECC0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85208>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85208>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F82406AB278>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85550>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8240626D30>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85208>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241EE8DD8>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8229C85550>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FCC5C0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FCC7F0>
# <PIL.Image.Image image mode=RGB size=256x256 at 0x7F8241FCC390>
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-58-cc7e2bf67b88> in <module>()
#       5 while cap.isOpened():
#       6     ret, image = cap.read()
# ----> 7     image = cv2.resize(image,(256,256))
#       8     cv2_imshow(image) # Note cv2_imshow, not cv2.imshow
#       9     result = get_result(image ,plot = False)
#
# error: OpenCV(4.1.2) /io/opencv/modules/imgproc/src/resize.cpp:3720: error: (-215:Assertion failed) !ssize.empty() in function 'resize'
